# %% [markdown]
# # Basic functions for a data frame using pandas library

# %%
# call libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1 import dataset

df=pd.read_excel("iris1.xls")

# %%
df.head(3) #we can put a number between () to display rows we need
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 0         NaN         NaN          Count       150.0
# 1         NaN         NaN        Minimum         4.3
# 2         NaN         NaN        Maximum         7.9

# %%
df.tail(3) #we can put a number between () to display rows we need
# Out:
#      sepal length  sepal width  petal length  petal width            iris  \
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 147         NaN         NaN            NaN         NaN
# 148         NaN         NaN            NaN         NaN
# 149         NaN         NaN            NaN         NaN

# %%
# get shape of dataset
df.shape
# Out:
# (150, 9)

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width  Unnamed: 5  \
# count    150.000000   150.000000    150.000000   150.000000         0.0
# mean       5.843333     3.054000      3.758667     1.198667         NaN
# std        0.828066     0.433594      1.764420     0.763161         NaN
# min        4.300000     2.000000      1.000000     0.100000         NaN
# 25%        5.100000     2.800000      1.600000     0.300000         NaN
# 50%        5.800000     3.000000      4.350000     1.300000         NaN
# 75%        6.400000     3.300000      5.100000     1.800000         NaN
# max        7.900000     4.400000      6.900000     2.500000         NaN
#
#        Unnamed: 6  Unnamed: 8
# count         0.0   13.000000
# mean          NaN   14.535512
# std           NaN   40.791727
# min           NaN   -0.552064
# 25%           NaN    0.685694
# 50%           NaN    4.300000
# 75%           NaN    5.800000
# max           NaN  150.000000

# %%
df.sort_values('sepal length', ascending = False) #sorting df according to a column value
# Out:
#      sepal length  sepal width  petal length  petal width            iris  \
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
#
#      Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# ...

# %%
df['Total sepal'] = df.iloc[1:2].sum(axis=1)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8  Total sepal
# 0         NaN         NaN          Count  150.000000          NaN
# 1         NaN         NaN        Minimum    4.300000         13.8
# 2         NaN         NaN        Maximum    7.900000          NaN
# 3         NaN         NaN           Mean    5.843333          NaN
# 4         NaN         NaN         Median    5.800000          NaN

# %%
#3 check datatypes of the features 
print(df.dtypes)
# Out:
# sepal length      float64
# sepal width       float64
# petal length      float64
# petal width       float64
# iris               object
# Unnamed: 5        float64
# Unnamed: 6        float64
# sepal length.1     object
# Unnamed: 8        float64
# Total sepal       float64
# dtype: object

# %%
# 4chaeck null values
df.isnull().sum()
# Out:
# sepal length        0
# sepal width         0
# petal length        0
# petal width         0
# iris                0
# Unnamed: 5        150
# Unnamed: 6        150
# sepal length.1    137
# Unnamed: 8        137
# Total sepal       149
# dtype: int64

# %%
#5Number of records of each classes 
Y = df.iris
Y.value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: iris, dtype: int64

# %% [markdown]
# ### way to read excel sheet

# %%
df_1=pd.read_excel("iris.xls")

# %%
df_1.head(3)
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 0         NaN         NaN          Count       150.0
# 1         NaN         NaN        Minimum         4.3
# 2         NaN         NaN        Maximum         7.9

# %% [markdown]
# ### Functions related to columns of dataset

# %%
df_1.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'iris',
#        'Unnamed: 5', 'Unnamed: 6', 'sepal length.1', 'Unnamed: 8'],
#       dtype='object')

# %%
df_1['sepal length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %%
#Droping unrelavent coloumns : option 1
df=df_1[df_1.columns[0:5]]
print(df)
# Out:
#      sepal length  sepal width  petal length  petal width            iris
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Droping unrelavent coloumns : option 2
df2=df.drop(columns = ["sepal width"] )
df2.head(3)
# Out:
#    sepal length  petal length  petal width         iris
# 0           5.1           1.4          0.2  Iris-setosa
# 1           4.9           1.4          0.2  Iris-setosa
# 2           4.7           1.3          0.2  Iris-setosa

# %%
df2['total']=df2['petal length']+df2['petal width']
df2.head(3)
# Out:
#    sepal length  petal length  petal width         iris  total
# 0           5.1           1.4          0.2  Iris-setosa    1.6
# 1           4.9           1.4          0.2  Iris-setosa    1.6
# 2           4.7           1.3          0.2  Iris-setosa    1.5

# %% [markdown]
# ### Functions related to rows of dataset

# %%
df_1.head(4) #can print until given number of rows
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 0         NaN         NaN          Count  150.000000
# 1         NaN         NaN        Minimum    4.300000
# 2         NaN         NaN        Maximum    7.900000
# 3         NaN         NaN           Mean    5.843333

# %%
df_1.iloc[50:60] #can print given range of rows
# Out:
#     sepal length  sepal width  petal length  petal width             iris  \
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 55           5.7          2.8           4.5          1.3  Iris-versicolor
# 56           6.3          3.3           4.7          1.6  Iris-versicolor
# 57           4.9          2.4           3.3          1.0  Iris-versicolor
# 58           6.6          2.9           4.6          1.3  Iris-versicolor
# 59           5.2          2.7           3.9          1.4  Iris-versicolor
#
#     Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 50         NaN         NaN            NaN         NaN
# ...

# %%
for index, row in df.iterrows():
    print(index,row["sepal length"])
# Out:
# 0 5.1
# 1 4.9
# 2 4.7
# 3 4.6
# 4 5.0
# 5 5.4
# 6 4.6
# 7 5.0
# 8 4.4
# 9 4.9
# 10 5.4
# 11 4.8
# 12 4.8
# 13 4.3
# 14 5.8
# 15 5.7
# 16 5.4
# 17 5.1
# 18 5.7
# 19 5.1
# 20 5.4
# 21 5.1
# 22 4.6
# 23 5.1
# 24 4.8
# 25 5.0
# 26 5.0
# 27 5.2
# 28 5.2
# 29 4.7
# 30 4.8
# 31 5.4
# 32 5.2
# 33 5.5
# 34 4.9
# 35 5.0
# 36 5.5
# 37 4.9
# 38 4.4
# 39 5.1
# 40 5.0
# 41 4.5
# 42 4.4
# 43 5.0
# 44 5.1
# 45 4.8
# 46 5.1
# 47 4.6
# 48 5.3
# 49 5.0
# 50 7.0
# 51 6.4
# 52 6.9
# 53 5.5
# 54 6.5
# 55 5.7
# 56 6.3
# 57 4.9
# 58 6.6
# 59 5.2
# 60 5.0
# 61 5.9
# 62 6.0
# 63 6.1
# 64 5.6
# 65 6.7
# 66 5.6
# 67 5.8
# 68 6.2
# 69 5.6
# 70 5.9
# 71 6.1
# 72 6.3
# 73 6.1
# 74 6.4
# 75 6.6
# 76 6.8
# 77 6.7
# 78 6.0
# 79 5.7
# 80 5.5
# 81 5.5
# 82 5.8
# 83 6.0
# 84 5.4
# 85 6.0
# 86 6.7
# 87 6.3
# 88 5.6
# 89 5.5
# 90 5.5
# 91 6.1
# 92 5.8
# 93 5.0
# 94 5.6
# 95 5.7
# 96 5.7
# 97 6.2
# 98 5.1
# 99 5.7
# 100 6.3
# 101 5.8
# 102 7.1
# 103 6.3
# 104 6.5
# 105 7.6
# 106 4.9
# 107 7.3
# 108 6.7
# 109 7.2
# 110 6.5
# ...

# %%
df_1.loc[df ["sepal length"] == 6.3]
# Out:
#      sepal length  sepal width  petal length  petal width             iris  \
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 123           6.3          2.7           4.9          1.8   Iris-virginica
# 133           6.3          2.8           5.1          1.5   Iris-virginica
# 136           6.3          3.4           5.6          2.4   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
#
#      Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 56          NaN         NaN            NaN         NaN
# 72          NaN         NaN            NaN         NaN
# ...

# %% [markdown]
# ### Filter the data

# %%
new_df = df_1.loc[(df['sepal length']==6.3) | (df['sepal width']>3.3)]
new_df.head()
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# 0         NaN         NaN          Count       150.0
# 4         NaN         NaN         Median         5.8
# 5         NaN         NaN           Mode         5.0
# 6         NaN         NaN     Quartile 1         5.1
# 7         NaN         NaN          Range         3.6

# %%
#6 Extract only the data of Iris-setosa and Iris_versicolor
df=df[(df['iris']=='Iris-setosa')|(df['iris']=='Iris-versicolor')]
df.head(101)
# Out:
#     sepal length  sepal width  petal length  petal width             iris
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# ..           ...          ...           ...          ...              ...
# 95           5.7          3.0           4.2          1.2  Iris-versicolor
# 96           5.7          2.9           4.2          1.3  Iris-versicolor
# 97           6.2          2.9           4.3          1.3  Iris-versicolor
# 98           5.1          2.5           3.0          1.1  Iris-versicolor
# 99           5.7          2.8           4.1          1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Save the data frames you created

# %%
# you can save in csv 
df.to_pickle ('seleted_cols.pk')

# %%
# how to read it again 
df= pd.read_pickle('seleted_cols.pk')

# %%
df.to_csv ('final datafraame.csv', index=False)

# %% [markdown]
# ## Data visualizing using matplotlib

# %%
#or
# select only two classes, according to give description of dataset 
# frist 100 records contain only Iris-setosa and Iris_versicolor
y=df.iloc[0:100,4].values

# %%
#7. now extract the first feature column (sepal length) and the third feature column (petal length) of those 100 training samples and assign them to a feature matrix X
X = df.iloc[0:100, [0, 2]].values

# %%
# visualize via a two-dimensional scatter plot
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='x', label='versicolor')
